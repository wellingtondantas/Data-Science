# %% [markdown]
# Utilizar visão computacional para identificar nos videos people-talking e people-walking pessoas falando e pessoas caminhando,
# gerando como saída um resultado similar aos vídeos people-talking-processed e people-walking-processed.
#
# Obs: Explique o que está sendo realizado em cada etapa.

# %%
#Bibliotecas
import cv2
import dlib
import imutils 

from google.colab import files
from google.colab.patches import cv2_imshow

# %%
#Faz o upload do arquivo
data = files.upload()
# Out:
#      <input type="file" id="files-56eb2b6e-b3dc-404d-8d1d-c7ea88c76a2d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56eb2b6e-b3dc-404d-8d1d-c7ea88c76a2d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving people-talking.mp4 to people-talking (2).mp4
# Saving shape.dat to shape.dat

# %%
#Abri o video
cap = cv2.VideoCapture('people-talking.mp4')

#Abri o treinamento
predictor = dlib.shape_predictor("shape.dat")

# %%
#Executa o modelo de detecção de pessoa falando
detector = dlib.get_frontal_face_detector()

while True:
    ret, frame = cap.read()
    if not ret: break
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    detections = detector(gray, 1) 
    for k,d in enumerate(detections):  
        shape = predictor(gray, d)  
        distance_month = compute_mouth_open_3pontos(shape, True) 
        cv2.putText(frame, str(distance_month), (30,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        for i in range(48-48,68-48): 
            cv2.circle(frame, (shape.part(i).x, shape.part(i).y), 2, (0,255,0), thickness=-1) 
        if distance_month >= 0.30: 
            cv2.putText(frame, "Talking!", (30,60), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
    #Mostra cada frame
    cv2_imshow(frame)

cap.release()
cv2.destroyAllWindows()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
